# %%
import cv2
import os
import numpy as np
import base64

# %%
original_img_path = os.path.join('..', '..', '..', '..', \
                       'DisqueDeDonnees', \
                       '3. ENIGMA Strasbourg - jeux et paperasse', \
                       '9.Reconnaissance-d-images', \
                       'images', '1.Lycée-Pontonniers', '2.pontonniers-49.jpg')

# %%
img = cv2.imread(original_img_path)
resized_image = cv2.resize(img, (int(img.shape[1] / 10), int(img.shape[0] / 10)))

# %%
cv2.imwrite()

# %%
resized_image.shape
# Out:
# (403, 301, 3)

# %%
str_test = base64.b64encode(resized_image)

# %%
str_test
# Out:
# b'...'

# %%
decoded = str_test.decode()

# %%
decoded
# Out:
# '...'

# %%
# cv2.imwrite('../test_image.jpeg', resized_image)

# %%
with open("../test_image.jpeg", "rb") as f:
    im_b64 = base64.b64encode(f.read())
    
im_bytes = base64.b64decode(im_b64)
im_arr = np.frombuffer(im_bytes, dtype=np.uint8)
img = cv2.imdecode(im_arr, flags=cv2.IMREAD_COLOR)

# %%
im_arr
# Out:
# array([255, 216, 255, ..., 167, 255, 217], dtype=uint8)

# %%
type(im_b64)
# Out:
# bytes

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %%
imgdata = base64.b64decode(img_str)
path_to_save_img = '../img_test_b64.jpg'

# %%
with open(path_to_save_img, 'wb') as f:
    f.write(imgdata)

# %%
import dash
import dash_html_components as html

# %%
html.Script()

# %%
html.Div()

# %%
html.Img(

# %%
app = dash.Dash()

# %%
app.scripts.append_script()

# %%
from flask import render_template

# %%
render_template()

# %% [markdown]
# #### Flask-SQLAlchemy

# %%
# !ls ../app_flask/main
# Out:
# forms.py     models.py	  routes.py  static	utils.py
# __init__.py  __pycache__  site.db    templates

# %%
import sys
sys.path.append('../app_flask')
from main import db
from main.models import User, Post
import flask_sqlalchemy
from datetime import datetime as dt
# Out:
# /home/ranto/.pyenv/versions/3.8.5/envs/vivadata/lib/python3.8/site-packages/flask_sqlalchemy/__init__.py:833: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   warnings.warn(FSADeprecationWarning(

# %%
User.query.filter_by(id='1').first().id
# Out:
# 1

# %%
users = User.query.all()

# %%
users
# Out:
# [User('Bertrand', 'bertrandburcker@gmail.com', 'default.png'),
#  User('clem', 'clem@hotmail.fr', 'default.png'),
#  User('Tom', 'Tom@machin.com', 'default.png'),
#  User('Pierre', 'Pierre@machin.com', 'default.png')]

# %%
Tom = User(username='Tom', email='Tom@machin.com', password="pass")

# %%
Pierre = User(username='Pierre', email='Pierre@machin.com', password='pass')

# %%
db.session.add(Tom)

# %%
db.session.add(Pierre)

# %%
db.session.commit()

# %%
date_1 = dt.utcnow()

# %%
date_2 = dt.utcnow()

# %%
date_3 = dt.utcnow()

# %%
posts = [
    {
        'title': 'La Société Mystérieuse de Strasbourg',
        'date': date_2,
        'content': "La Société Mystérieuse de Strasbourg compte de nombreux érudits qui \
        ont façonné la ville de Strasbourg. Ils vous ont laissé quelques énigmes afin de \
        rencontrer les meilleurs d’entre vous, de vous tester et peut-être même de les \
        rejoindre.\
        \nSerez-vous de taille à résoudre les énigmes des grandes figures qui ont contribué \
        au prestige de Strasbourg ?",
        "user_id": 1
    },
    {
        'title': '1913, Meurtre à la Krutenau',
        'date': date_3,
        'content': "“Mon arrière grand-père est un assassin selon les archives \
        historiques. Aidez-moi à fouiller le passé pour le prouver ou le démentir” \
        \nJean est en possession d’une lettre d’un aïeul contredisant les archives \
        historiques qui font de son arrière-grand père l’auteur du Meurtre à la \
        Krutenau. Il vous sollicite pour investiguer et connaître la vérité. \
        Une Machine à Immersion Spatio-Temporelle devrait vous permettre de revoir \
        certaines scènes et de comprendre ce qu’il s’est passé.",
        "user_id": 1
    },
    {
        'title': 'ENIGMA Strasbourg',
        'date': date_1,
        'content': "Percez les mystères de Strasbourg et explorez la ville.\
        \nVous avez aimé les escape games ? Alors relevez le défi des jeux de \
        piste ENIGMA Strasbourg. Nul besoin de s’échapper, seulement de s’évader !\
        \nLes jeux de piste ENIGMA Strasbourg sont des jeux géants et se déroulent \
        en extérieur. Parcourez en autonomie, revisitez à votre rythme l’hypercentre \
        de Strasbourg à travers différents jeux de piste ou enquêtes.\
        \nBientôt de retour à Strasbourg.",
        "user_id": 1
    }
]

# %%
posts
# Out:
# [{'title': 'La Société Mystérieuse de Strasbourg',
#   'date': datetime.datetime(2020, 11, 6, 11, 11, 39, 485027),
#   'content': 'La Société Mystérieuse de Strasbourg compte de nombreux érudits qui         ont façonné la ville de Strasbourg. Ils vous ont laissé quelques énigmes afin de         rencontrer les meilleurs d’entre vous, de vous tester et peut-être même de les         rejoindre.        \nSerez-vous de taille à résoudre les énigmes des grandes figures qui ont contribué         au prestige de Strasbourg ?',
#   'user_id': 1},
#  {'title': '1913, Meurtre à la Krutenau',
#   'date': datetime.datetime(2020, 11, 6, 11, 11, 40, 504510),
# ...

# %%
for post in posts:
    db.session.add(Post(title=post['title'], 
                        date=post['date'], 
                        content=post['content'], 
                        user_id=1))

# %%
db.session.commit()

# %%
all_post = Post.query.paginate(per_page=2, page=2)

# %%
dir(all_post)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'has_next',
#  'has_prev',
#  'items',
#  'iter_pages',
#  'next',
#  'next_num',
#  'page',
#  'pages',
#  'per_page',
#  'prev',
#  'prev_num',
#  'query',
#  'total']

# %%
for page in all_post.iter_pages():
    print(page)
# Out:
# 1
# 2

# %%
all_post

# %%
from itsdangerous import TimedJSONWebSignatureSerializer as Serializer

# %%
s = Serializer('secret', 30)

# %%
token = s.dumps({'user_id': 1}).decode('utf-8')

# %%
s.loads(token)
# Out:
# ---------------------------------------------------------------------------
# SignatureExpired                          Traceback (most recent call last)
# <ipython-input-51-985dc7d1ce4d> in <module>
# ----> 1 s.loads(token)
#
# ~/.pyenv/versions/3.8.5/envs/vivadata/lib/python3.8/site-packages/itsdangerous/jws.py in loads(self, s, salt, return_header)
#     200
#     201         if header["exp"] < self.now():
# --> 202             raise SignatureExpired(
#     203                 "Signature expired",
#     204                 payload=payload,
#
# SignatureExpired: Signature expired

# %%
# !ls ../app_flask/flask_project
# Out:
# config.json  errors	  main	     pages  __pycache__  static     users
# config.py    __init__.py  models.py  posts  site.db	 templates

# %%
import json
import sys
sys.path.append('../app_flask/flask_project')

# %%
with open('../app_flask/flask_project/config.json') as f:
    config = json.load(f)

# %%
config
# Out:
# {'SECRET_KEY': '12b71d0522464200e53620635bd21121',
#  'SQLALCHEMY_DATABASE_URI': 'sqlite:///site.db',
#  'MAIL_USERNAME': 'contact@enigmastrasbourg.com',
#  'MAIL_PASSWORD': 'BHU&85@edpa'}
